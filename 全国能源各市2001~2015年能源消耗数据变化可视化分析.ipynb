# %%
import pandas as pd

# %%
filePath_01 = '/Users/hangzhaoli/Desktop/Pro_29.xlsx'

# %%
df1 = pd.read_excel(filePath_01,sheet_name = 'Anyang2001').T

# %%
s1 = df1[1]

# %%
s1.to_csv('ay2001.csv')

# %%
df2 = pd.read_excel(filePath_01,sheet_name = 'Anyang2003').T

# %%
s2 = df2[1]

# %%
s2.to_csv('ay2002.csv')

# %%
df3 = pd.read_excel(filePath_01,sheet_name = 'Anyang2004').T

# %%
s3 = df3[1]

# %%
s3.to_csv('ay2004.csv')

# %%
df4 = pd.read_excel(filePath_01,sheet_name = 'Anyang2007').T

# %%
s4 = df4[1]

# %%
s4.to_csv('ay2007.csv')

# %%
df5 = pd.read_excel(filePath_01,sheet_name = 'Anyang2008').T

# %%
s5 = df5[1]

# %%
df6 = pd.read_excel(filePath_01,sheet_name = 'Anyang2009').T

# %%
df7 = pd.read_excel(filePath_01,sheet_name = 'Anyang2011').T

# %%
df8 = pd.read_excel(filePath_01,sheet_name = 'Anyang2012').T

# %%
df9 = pd.read_excel(filePath_01,sheet_name = 'Anyang2013').T

# %%
df10 = pd.read_excel(filePath_01,sheet_name = 'Anyang2014').T

# %%
df11 = pd.read_excel(filePath_01,sheet_name = 'Anyang2015').T

# %%
s6 =df6[1]
s7 =df7[1]
s8 =df8[1]
s9 =df9[1]
s10 =df10[1]
s11 =df11[1]

# %%
data = pd.concat([s1,s2,s3,s4,s5,s6,s7,s8,s9,s10,s11],axis = 1)

# %%
data
# Out:
#                                                 1                        1  \
# Unnamed: 0                Total Final Consumption  Total Final Consumption
# Raw Coal                                  872.511                  657.147
# Cleaned Coal                               318.31                  334.298
# Other Washed Coal                         3.93716                  4.87004
# Briquettes                                 2.1069                  2.00174
# Coke                                      392.806                  475.357
# Coke Oven Gas                             8.81176                  8.41074
# Other Gas                                 75.5099                  78.8565
# Other Coking Products                      2.4625                        0
# Crude Oil                               -0.708797                 -34.0808
# Gasoline                                     5.38                  4.59018
# ...

# %%
dm = data.T

# %%
dm
# Out:
#                 Unnamed: 0 Raw Coal Cleaned Coal Other Washed Coal Briquettes  \
# 1  Total Final Consumption  872.511       318.31           3.93716     2.1069
# 1  Total Final Consumption  657.147      334.298           4.87004    2.00174
# 1  Total Final Consumption  717.318      389.993           1.07811    2.44864
# 1  Total Final Consumption  1872.38      354.473           5.74395    1.03496
# 1  Total Final Consumption  1926.84      155.559           7.74454    1.03911
# 1  Total Final Consumption  1887.39      298.944           8.55153   0.706997
# 1  Total Final Consumption  590.942      1287.88          -3.48588    12.8921
# 1  Total Final Consumption  399.757      901.647            -2.279    12.9799
# 1  Total Final Consumption  517.839         1233          -6.56477    2.67031
# 1  Total Final Consumption  605.452      1426.01          -5.34294    4.97088
# 1  Total Final Consumption  529.757      1765.46          -7.08363    1.20767
#
# ...

# %%
dm.reset_index(inplace=True,drop=True)

# %%
dm
# Out:
#                  Unnamed: 0 Raw Coal Cleaned Coal Other Washed Coal  \
# 0   Total Final Consumption  872.511       318.31           3.93716
# 1   Total Final Consumption  657.147      334.298           4.87004
# 2   Total Final Consumption  717.318      389.993           1.07811
# 3   Total Final Consumption  1872.38      354.473           5.74395
# 4   Total Final Consumption  1926.84      155.559           7.74454
# 5   Total Final Consumption  1887.39      298.944           8.55153
# 6   Total Final Consumption  590.942      1287.88          -3.48588
# 7   Total Final Consumption  399.757      901.647            -2.279
# 8   Total Final Consumption  517.839         1233          -6.56477
# 9   Total Final Consumption  605.452      1426.01          -5.34294
# 10  Total Final Consumption  529.757      1765.46          -7.08363
#
#    Briquettes     Coke Coke Oven Gas Other Gas Other Coking Products  \
# 0      2.1069  392.806       8.81176   75.5099                2.4625
# ...

# %%
dm.rename(index ={0:2001,1:2003,2:2004,3:2007,4:2008,5:2009,6:2011,7:2012,8:2013,9:2014,10:2015},inplace=True)

# %%
dm
# Out:
#                    Unnamed: 0 Raw Coal Cleaned Coal Other Washed Coal  \
# 2001  Total Final Consumption  872.511       318.31           3.93716
# 2003  Total Final Consumption  657.147      334.298           4.87004
# 2004  Total Final Consumption  717.318      389.993           1.07811
# 2007  Total Final Consumption  1872.38      354.473           5.74395
# 2008  Total Final Consumption  1926.84      155.559           7.74454
# 2009  Total Final Consumption  1887.39      298.944           8.55153
# 2011  Total Final Consumption  590.942      1287.88          -3.48588
# 2012  Total Final Consumption  399.757      901.647            -2.279
# 2013  Total Final Consumption  517.839         1233          -6.56477
# 2014  Total Final Consumption  605.452      1426.01          -5.34294
# 2015  Total Final Consumption  529.757      1765.46          -7.08363
#
#      Briquettes     Coke Coke Oven Gas Other Gas Other Coking Products  \
# ...

# %%
import seaborn as sns

# %%
dm.T
# Out:
#                                              2001                     2003  \
# Unnamed: 0                Total Final Consumption  Total Final Consumption
# Raw Coal                                  872.511                  657.147
# Cleaned Coal                               318.31                  334.298
# Other Washed Coal                         3.93716                  4.87004
# Briquettes                                 2.1069                  2.00174
# Coke                                      392.806                  475.357
# Coke Oven Gas                             8.81176                  8.41074
# Other Gas                                 75.5099                  78.8565
# Other Coking Products                      2.4625                        0
# Crude Oil                               -0.708797                 -34.0808
# Gasoline                                     5.38                  4.59018
# ...

# %%
dt = dm.drop(columns=['Unnamed: 0'])

# %%
dt
# Out:
#      Raw Coal Cleaned Coal Other Washed Coal Briquettes     Coke  \
# 2001  872.511       318.31           3.93716     2.1069  392.806
# 2003  657.147      334.298           4.87004    2.00174  475.357
# 2004  717.318      389.993           1.07811    2.44864  520.192
# 2007  1872.38      354.473           5.74395    1.03496  836.841
# 2008  1926.84      155.559           7.74454    1.03911  827.484
# 2009  1887.39      298.944           8.55153   0.706997  822.763
# 2011  590.942      1287.88          -3.48588    12.8921  733.671
# 2012  399.757      901.647            -2.279    12.9799  676.295
# 2013  517.839         1233          -6.56477    2.67031  769.978
# 2014  605.452      1426.01          -5.34294    4.97088  740.465
# 2015  529.757      1765.46          -7.08363    1.20767  707.681
#
#      Coke Oven Gas Other Gas Other Coking Products Crude Oil Gasoline  \
# 2001       8.81176   75.5099                2.4625 -0.708797     5.38
# ...

# %%
dt.to_csv('安阳数据汇总.csv')

# %%
dt['Raw Coal'].plot()

# %%
dt['Cleaned Coal'].plot()

# %%
dt['Other Washed Coal'].plot()

# %%
dt['Gasoline'].plot()

# %%
dt['Natural Gas'].plot()

# %%
dt['Heat'].plot()

# %%
dt['Electricity'].plot()

# %%
dt
# Out:
#      Raw Coal Cleaned Coal Other Washed Coal Briquettes     Coke  \
# 2001  872.511       318.31           3.93716     2.1069  392.806
# 2003  657.147      334.298           4.87004    2.00174  475.357
# 2004  717.318      389.993           1.07811    2.44864  520.192
# 2007  1872.38      354.473           5.74395    1.03496  836.841
# 2008  1926.84      155.559           7.74454    1.03911  827.484
# 2009  1887.39      298.944           8.55153   0.706997  822.763
# 2011  590.942      1287.88          -3.48588    12.8921  733.671
# 2012  399.757      901.647            -2.279    12.9799  676.295
# 2013  517.839         1233          -6.56477    2.67031  769.978
# 2014  605.452      1426.01          -5.34294    4.97088  740.465
# 2015  529.757      1765.46          -7.08363    1.20767  707.681
#
#      Coke Oven Gas Other Gas Other Coking Products Crude Oil Gasoline  \
# 2001       8.81176   75.5099                2.4625 -0.708797     5.38
# ...

# %%
df1 = pd.read_excel(filePath_01,sheet_name = 'Jiaozuo2004').T

# %%
s1 = df1[1]

# %%
s1
# Out:
# Unnamed: 0                  Total Final Consumption
# Raw Coal                                    1821.89
# Cleaned Coal                                4.74961
# Other Washed Coal                           4.06635
# Briquettes                                 0.390868
# Coke                                        26.2493
# Coke Oven Gas                                     0
# Other Gas                                   1.72384
# Other Coking Products                      0.609351
# Crude Oil                                -0.0661538
# Gasoline                                    15.9952
# Kerosene                                   0.880825
# Diesel Oil                                  17.0102
# Fuel Oil                                      3.085
# LPG                                         1.36868
# Refinery Gas                              -0.255385
# Other Petroleum Products                    5.85974
# Natural Gas                                 0.18585
# ...

# %%
df1 = pd.read_excel(filePath_01,sheet_name = 'Jiaozuo2004').T
df2 = pd.read_excel(filePath_01,sheet_name = 'Jiaozuo2005').T
df3 = pd.read_excel(filePath_01,sheet_name = 'Jiaozuo2006').T
df4 = pd.read_excel(filePath_01,sheet_name = 'Jiaozuo2007').T
df5 = pd.read_excel(filePath_01,sheet_name = 'Jiaozuo2008').T
df6 = pd.read_excel(filePath_01,sheet_name = 'Jiaozuo2009').T
df7 = pd.read_excel(filePath_01,sheet_name = 'Jiaozuo2010').T
df8 = pd.read_excel(filePath_01,sheet_name = 'Jiaozuo2011').T
df9 = pd.read_excel(filePath_01,sheet_name = 'Jiaozuo2012').T
df10 = pd.read_excel(filePath_01,sheet_name = 'Jiaozuo2013').T
df11 = pd.read_excel(filePath_01,sheet_name = 'Jiaozuo2014').T
df12 = pd.read_excel(filePath_01,sheet_name = 'Jiaozuo2015').T
s2 = df2[1]
s3 = df3[1]
s4 = df4[1]
s5 = df5[1]
s6 = df6[1]
s7 = df7[1]
s8 = df8[1]
s9 = df9[1]
s10 = df10[1]
s11 = df11[1]
s12 = df12[1]

# %%
dq = pd.concat([s1,s2,s3,s4,s5,s6,s7,s8,s9,s10,s11,s12])

# %%
s4
# Out:
# Unnamed: 0                  Total Final Consumption
# Raw Coal                                    1943.62
# Cleaned Coal                               -13.3144
# Other Washed Coal                           1.44506
# Briquettes                                  14.1764
# Coke                                        72.1908
# Coke Oven Gas                             -0.082365
# Other Gas                                 -0.215909
# Other Coking Products                      0.855285
# Crude Oil                                  -10.2567
# Gasoline                                    16.5215
# Kerosene                                    1.49899
# Diesel Oil                                  31.7288
# Fuel Oil                                    1.24722
# LPG                                          1.4936
# Refinery Gas                              -0.554554
# Other Petroleum Products                    11.7225
# Natural Gas                                0.577312
# ...

# %%
dq = pd.concat([s1,s2,s3,s4,s5,s6,s7,s8,s9,s10,s11,s12],axis = 1)

# %%
dq.T
# Out:
#                 Unnamed: 0 Raw Coal Cleaned Coal Other Washed Coal Briquettes  \
# 1  Total Final Consumption  1821.89      4.74961           4.06635   0.390868
# 1  Total Final Consumption  1988.84      9.70732          -4.74552   0.831603
# 1  Total Final Consumption  1859.74      10.8238          -2.30974    5.11952
# 1  Total Final Consumption  1943.62     -13.3144           1.44506    14.1764
# 1  Total Final Consumption  2070.04     -13.1644           2.00868    2.20232
# 1  Total Final Consumption  1729.16     -21.8467           23.4584    67.5127
# 1  Total Final Consumption  1368.65     -46.2915           30.8681    80.8153
# 1  Total Final Consumption  803.511     -48.1323           51.4758    5.53701
# 1  Total Final Consumption  334.642     -43.8783          -7.64351    5.18946
# 1  Total Final Consumption  402.527     -68.4268          -7.34736          0
# 1  Total Final Consumption  429.386     -37.0177           61.5136   0.782664
# ...

# %%
d22=dq.T

# %%
ds = d22.drop(columns=['Unnamed: 0'])

# %%
ds
# Out:
#   Raw Coal Cleaned Coal Other Washed Coal Briquettes     Coke Coke Oven Gas  \
# 1  1821.89      4.74961           4.06635   0.390868  26.2493             0
# 1  1988.84      9.70732          -4.74552   0.831603     58.1     0.0268185
# 1  1859.74      10.8238          -2.30974    5.11952  76.5574    0.00788663
# 1  1943.62     -13.3144           1.44506    14.1764  72.1908     -0.082365
# 1  2070.04     -13.1644           2.00868    2.20232  63.3911    -0.0953207
# 1  1729.16     -21.8467           23.4584    67.5127  101.335     -0.117163
# 1  1368.65     -46.2915           30.8681    80.8153  108.875      0.333923
# 1  803.511     -48.1323           51.4758    5.53701  95.4676     -0.336832
# 1  334.642     -43.8783          -7.64351    5.18946   49.685     -0.235815
# 1  402.527     -68.4268          -7.34736          0  25.9765     -0.298367
# 1  429.386     -37.0177           61.5136   0.782664   41.614     -0.559646
# ...

# %%
ds.reset_index(inplace=True,drop=True)

# %%
ds
# Out:
#    Raw Coal Cleaned Coal Other Washed Coal Briquettes     Coke Coke Oven Gas  \
# 0   1821.89      4.74961           4.06635   0.390868  26.2493             0
# 1   1988.84      9.70732          -4.74552   0.831603     58.1     0.0268185
# 2   1859.74      10.8238          -2.30974    5.11952  76.5574    0.00788663
# 3   1943.62     -13.3144           1.44506    14.1764  72.1908     -0.082365
# 4   2070.04     -13.1644           2.00868    2.20232  63.3911    -0.0953207
# 5   1729.16     -21.8467           23.4584    67.5127  101.335     -0.117163
# 6   1368.65     -46.2915           30.8681    80.8153  108.875      0.333923
# 7   803.511     -48.1323           51.4758    5.53701  95.4676     -0.336832
# 8   334.642     -43.8783          -7.64351    5.18946   49.685     -0.235815
# 9   402.527     -68.4268          -7.34736          0  25.9765     -0.298367
# 10  429.386     -37.0177           61.5136   0.782664   41.614     -0.559646
# ...

# %%
ds.rename(index ={0:2004,1:2005,2:2006,3:2007,4:2008,5:2009,6:2010,7:2011,8:2012,9:2013,10:2014,11:2015},inplace=True)

# %%
ds
# Out:
#      Raw Coal Cleaned Coal Other Washed Coal Briquettes     Coke  \
# 2004  1821.89      4.74961           4.06635   0.390868  26.2493
# 2005  1988.84      9.70732          -4.74552   0.831603     58.1
# 2006  1859.74      10.8238          -2.30974    5.11952  76.5574
# 2007  1943.62     -13.3144           1.44506    14.1764  72.1908
# 2008  2070.04     -13.1644           2.00868    2.20232  63.3911
# 2009  1729.16     -21.8467           23.4584    67.5127  101.335
# 2010  1368.65     -46.2915           30.8681    80.8153  108.875
# 2011  803.511     -48.1323           51.4758    5.53701  95.4676
# 2012  334.642     -43.8783          -7.64351    5.18946   49.685
# 2013  402.527     -68.4268          -7.34736          0  25.9765
# 2014  429.386     -37.0177           61.5136   0.782664   41.614
# 2015  663.763     -39.5758           76.2548   0.938301  6.84927
#
#      Coke Oven Gas   Other Gas Other Coking Products  Crude Oil Gasoline  \
# ...

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
fig5, ax5 = plt.subplots(3,2)

# %%
ds['Raw Coal'].plot(ax =ax5[0,0])

# %%
ds['Natural Gas'].plot(ax =ax5[0,1])

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib
 
plt.rcParams['font.sans-serif'] = ['SimHei']    # 用来正常显示中文字符
plt.rcParams['axes.unicode_minus'] = False

fig= plt.figure()

ax = fig.add_axes([0,0,1,1])
ax.plot(label='X Squared')
ax.plot(label='X Cubed')
ax.set_title('Jiaozuo')
ds['Electricity'].plot()
ax.legend(loc = 2) #把标识放入的位置
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-701969b7934c> in <module>
#      12 ax.plot(label='X Cubed')
#      13 ax.set_title('Jiaozuo')
# ---> 14 ds['Electricity'].plot()
#      15 ax.legend(loc = 2) #把标识放入的位置
#
# NameError: name 'ds' is not defined

# %%
import pandas as pd
filePath_01 = '/Users/hangzhaoli/Desktop/Pro_29.xlsx'
df1 = pd.read_excel(filePath_01,sheet_name = 'Zhengzhou2000').T
df2 = pd.read_excel(filePath_01,sheet_name = 'Jiyuan2002').T
df3 = pd.read_excel(filePath_01,sheet_name = 'Jiyuan2003').T
df4 = pd.read_excel(filePath_01,sheet_name = 'Jiyuan2005').T
df5 = pd.read_excel(filePath_01,sheet_name = 'Jiyuan2006').T
df6 = pd.read_excel(filePath_01,sheet_name = 'Jiyuan2007').T
df7 = pd.read_excel(filePath_01,sheet_name = 'Jiyuan2008').T
df8 = pd.read_excel(filePath_01,sheet_name = 'Jiyuan2009').T
df9 = pd.read_excel(filePath_01,sheet_name = 'Jiyuan2010').T
df10 = pd.read_excel(filePath_01,sheet_name = 'Jiyuan2012').T
df11 = pd.read_excel(filePath_01,sheet_name = 'Jiyuan2013').T
df12 = pd.read_excel(filePath_01,sheet_name = 'Jiyuan2014').T
df13 = pd.read_excel(filePath_01,sheet_name = 'Jiyuan2015').T
s1 = df1[1]
s2 = df2[1]
s3 = df3[1]
s4 = df4[1]
s5 = df5[1]
s6 = df6[1]
s7 = df7[1]
s8 = df8[1]
s9 = df9[1]
s10 = df10[1]
s11 = df11[1]
s12 = df12[1]
s13 = df13[1]

# %%
dq = pd.concat([s1,s2,s3,s4,s5,s6,s7,s8,s9,s10,s11,s12,s13],axis = 1)

# %%
ds = dq.T

# %%
ds
# Out:
#                 Unnamed: 0 Raw Coal Cleaned Coal Other Washed Coal Briquettes  \
# 1  Total Final Consumption  1010.76     -1.55614          -5.45191   0.186166
# 1  Total Final Consumption  251.207      33.1332          0.201596          0
# 1  Total Final Consumption  164.482      155.167         0.0706923          0
# 1  Total Final Consumption  199.336      110.138           2.43371   0.245382
# 1  Total Final Consumption  212.966      122.886          0.677482          0
# 1  Total Final Consumption  243.291      113.869           1.73926   0.176715
# 1  Total Final Consumption  205.049      97.0573           5.94874    1.14125
# 1  Total Final Consumption  216.929      105.367            8.0884   0.598826
# 1  Total Final Consumption  162.584      84.9205           6.86127   0.538539
# 1  Total Final Consumption  182.714       88.566           12.2003   0.943616
# 1  Total Final Consumption  189.833      97.2371           11.5299          0
# ...

# %%
dm = ds.drop(columns=['Unnamed: 0'])

# %%
dm
# Out:
#   Raw Coal Cleaned Coal Other Washed Coal Briquettes     Coke Coke Oven Gas  \
# 1  1010.76     -1.55614          -5.45191   0.186166  -2.2774     0.0346239
# 1  251.207      33.1332          0.201596          0  93.2599     0.0190768
# 1  164.482      155.167         0.0706923          0  103.889     0.0304647
# 1  199.336      110.138           2.43371   0.245382  92.2489      0.193233
# 1  212.966      122.886          0.677482          0  127.897      0.505986
# 1  243.291      113.869           1.73926   0.176715  139.547       1.48911
# 1  205.049      97.0573           5.94874    1.14125  151.693       2.30684
# 1  216.929      105.367            8.0884   0.598826  141.576       2.91537
# 1  162.584      84.9205           6.86127   0.538539  137.321       3.31031
# 1  182.714       88.566           12.2003   0.943616  148.047       2.60431
# 1  189.833      97.2371           11.5299          0  160.919      -9.31089
# ...

# %%
dm.reset_index(inplace=True,drop=True)

# %%
dm
# Out:
#    Raw Coal Cleaned Coal Other Washed Coal Briquettes     Coke Coke Oven Gas  \
# 0   1010.76     -1.55614          -5.45191   0.186166  -2.2774     0.0346239
# 1   251.207      33.1332          0.201596          0  93.2599     0.0190768
# 2   164.482      155.167         0.0706923          0  103.889     0.0304647
# 3   199.336      110.138           2.43371   0.245382  92.2489      0.193233
# 4   212.966      122.886          0.677482          0  127.897      0.505986
# 5   243.291      113.869           1.73926   0.176715  139.547       1.48911
# 6   205.049      97.0573           5.94874    1.14125  151.693       2.30684
# 7   216.929      105.367            8.0884   0.598826  141.576       2.91537
# 8   162.584      84.9205           6.86127   0.538539  137.321       3.31031
# 9   182.714       88.566           12.2003   0.943616  148.047       2.60431
# 10  189.833      97.2371           11.5299          0  160.919      -9.31089
# ...

# %%
dm.rename(index ={0:2001,1:2002,2:2003,3:2005,4:2006,5:2007,6:2008,7:2009,8:2010,9:2012,10:2013,11:2014,12:2015},inplace=True)

# %%
dm
# Out:
#      Raw Coal Cleaned Coal Other Washed Coal Briquettes     Coke  \
# 2001  1010.76     -1.55614          -5.45191   0.186166  -2.2774
# 2002  251.207      33.1332          0.201596          0  93.2599
# 2003  164.482      155.167         0.0706923          0  103.889
# 2005  199.336      110.138           2.43371   0.245382  92.2489
# 2006  212.966      122.886          0.677482          0  127.897
# 2007  243.291      113.869           1.73926   0.176715  139.547
# 2008  205.049      97.0573           5.94874    1.14125  151.693
# 2009  216.929      105.367            8.0884   0.598826  141.576
# 2010  162.584      84.9205           6.86127   0.538539  137.321
# 2012  182.714       88.566           12.2003   0.943616  148.047
# 2013  189.833      97.2371           11.5299          0  160.919
# 2014  193.952       92.918            15.134   0.126536  166.589
# 2015  158.708      86.9255           7.81645    0.17407  157.706
#
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib
 
plt.rcParams['font.sans-serif'] = ['SimHei']    # 用来正常显示中文字符
plt.rcParams['axes.unicode_minus'] = False

fig= plt.figure()

ax = fig.add_axes([0,0,1,1])
ax.plot(label='X Squared')
ax.plot(label='X Cubed')
ax.set_title('Jiyuan')
dm['Electricity'].plot()
ax.legend(loc = 2) #把标识放入的位置

# %%
dm.plot(figsize = (10,12),subplots = True);

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib
 

fig= plt.figure()

ax = fig.add_axes([0,0,1,1])
ax.plot(label='X Squared')
ax.plot(label='X Cubed')
ax.set_title('Jiyuan')
dm['Raw Coal'].plot()
ax.legend(loc = 1)

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib
 

fig= plt.figure()

ax = fig.add_axes([0,0,1,1])
ax.plot(label='X Squared')
ax.plot(label='X Cubed')
ax.set_title('Jiyuan')
dm['Gasoline'].plot()
ax.legend(loc = 1)

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib
 

fig= plt.figure()

ax = fig.add_axes([0,0,1,1])
ax.plot(label='X Squared')
ax.plot(label='X Cubed')
ax.set_title('Jiyuan')
dm['Natural Gas'].plot()
ax.legend(loc = 2)

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib
 

fig= plt.figure()

ax = fig.add_axes([0,0,1,1])
ax.plot(label='X Squared')
ax.plot(label='X Cubed')
ax.set_title('Jiyuan')
dm['Heat'].plot()
ax.legend(loc = 2)

# %%
df1 = pd.read_excel(filePath_01,sheet_name = 'Luoyang2000').T
df2 = pd.read_excel(filePath_01,sheet_name = 'Luoyang2001').T
df3 = pd.read_excel(filePath_01,sheet_name = 'Luoyang2002').T
df4 = pd.read_excel(filePath_01,sheet_name = 'Luoyang2003').T
df5 = pd.read_excel(filePath_01,sheet_name = 'Luoyang2004').T
df6 = pd.read_excel(filePath_01,sheet_name = 'Luoyang2005').T
df7 = pd.read_excel(filePath_01,sheet_name = 'Luoyang2006').T
df8 = pd.read_excel(filePath_01,sheet_name = 'Luoyang2007').T
df9 = pd.read_excel(filePath_01,sheet_name = 'Luoyang2008').T
df10 = pd.read_excel(filePath_01,sheet_name = 'Luoyang2009').T
df11 = pd.read_excel(filePath_01,sheet_name = 'Luoyang2010').T
df12 = pd.read_excel(filePath_01,sheet_name = 'Luoyang2011').T
df13 = pd.read_excel(filePath_01,sheet_name = 'Luoyang2012').T
df14 = pd.read_excel(filePath_01,sheet_name = 'Luoyang2013').T
df15 = pd.read_excel(filePath_01,sheet_name = 'Luoyang2014').T
df16 = pd.read_excel(filePath_01,sheet_name = 'Luoyang2015').T


s1 = df1[1]
s2 = df2[1]
s3 = df3[1]
s4 = df4[1]
s5 = df5[1]
s6 = df6[1]
s7 = df7[1]
s8 = df8[1]
s9 = df9[1]
s10 = df10[1]
s11 = df11[1]
s12 = df12[1]
s13 = df13[1]
s14 = df14[1]
s15 = df15[1]
s16 = df16[1]

dq = pd.concat([s1,s2,s3,s4,s5,s6,s7,s8,s9,s10,s11,s12,s13,s14,s15,s16],axis = 1)
ds = dq.T
dm = ds.drop(columns=['Unnamed: 0'])
dm.reset_index(inplace=True,drop=True)
dm.rename(index ={0:2000,1:2001,2:2002,3:2003,4:2004,5:2005,6:2006,7:2007,8:2008,9:2009,10:2010,11:2011,12:2012,13:2013,14:2014,15:2015},inplace=True)

# %%
dm.plot(figsize = (10,12),subplots = True);

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib
 
plt.rcParams['font.sans-serif'] = ['SimHei']    # 用来正常显示中文字符
plt.rcParams['axes.unicode_minus'] = False

fig= plt.figure()

ax = fig.add_axes([0,0,1,1])
ax.plot(label='X Squared')
ax.plot(label='X Cubed')
ax.set_title('Luoyang')
dm['Raw Coal'].plot()
ax.legend(loc = 1) #把标识放入的位置

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib
 
plt.rcParams['font.sans-serif'] = ['SimHei']    # 用来正常显示中文字符
plt.rcParams['axes.unicode_minus'] = False

fig= plt.figure()

ax = fig.add_axes([0,0,1,1])
ax.plot(label='X Squared')
ax.plot(label='X Cubed')
ax.set_title('Luoyang')
dm['Electricity'].plot()
ax.legend(loc = 2) #把标识放入的位置

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib
 
plt.rcParams['font.sans-serif'] = ['SimHei']    # 用来正常显示中文字符
plt.rcParams['axes.unicode_minus'] = False

fig= plt.figure()

ax = fig.add_axes([0,0,1,1])
ax.plot(label='X Squared')
ax.plot(label='X Cubed')
ax.set_title('Luoyang')
dm['Gasoline'].plot()
ax.legend(loc = 2) #把标识放入的位置

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib
 
plt.rcParams['font.sans-serif'] = ['SimHei']    # 用来正常显示中文字符
plt.rcParams['axes.unicode_minus'] = False

fig= plt.figure()

ax = fig.add_axes([0,0,1,1])
ax.plot(label='X Squared')
ax.plot(label='X Cubed')
ax.set_title('Luoyang')
dm['Natural Gas'].plot()
ax.legend(loc = 2) #把标识放入的位置

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib
 
plt.rcParams['font.sans-serif'] = ['SimHei']    # 用来正常显示中文字符
plt.rcParams['axes.unicode_minus'] = False

fig= plt.figure()

ax = fig.add_axes([0,0,1,1])
ax.plot(label='X Squared')
ax.plot(label='X Cubed')
ax.set_title('Luoyang')
dm['Heat'].plot()
ax.legend(loc = 2) #把标识放入的位置

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib
 
plt.rcParams['font.sans-serif'] = ['SimHei']    # 用来正常显示中文字符
plt.rcParams['axes.unicode_minus'] = False

fig= plt.figure()

ax = fig.add_axes([0,0,1,1])
ax.plot(label='X Squared')
ax.plot(label='X Cubed')
ax.set_title('Zhengzhou')
dm['Heat'].plot()
ax.legend(loc = 2) #把标识放入的位置

# %%
dm.(iloc2000)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-82-5bb7060f2ea8> in <module>
# ----> 1 dm.iloc(2000)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __call__(self, axis)
#     575
#     576         if axis is not None:
# --> 577             axis = self.obj._get_axis_number(axis)
#     578         new_self.axis = axis
#     579         return new_self
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     405             except KeyError:
#     406                 pass
# --> 407         raise ValueError(f"No axis named {axis} for object type {cls}")
#     408
#     409     @classmethod
#
# ValueError: No axis named 2000 for object type <class 'pandas.core.frame.DataFrame'>

# %%
dm.loc[2009] 
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
s = dm.loc[2009].sort_values(ascending = False)

# %%
fig, ax1 = plt.subplots()
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
s.plot.bar(ax =ax1)

# %%
s.plot.bar(ax= ax2[0])

# %%
df1 = pd.read_excel(filePath_01,sheet_name = 'Zhengzhou2000').T
df2 = pd.read_excel(filePath_01,sheet_name = 'Zhengzhou2001').T
df3 = pd.read_excel(filePath_01,sheet_name = 'Zhengzhou2002').T
df4 = pd.read_excel(filePath_01,sheet_name = 'Zhengzhou2003').T
df5 = pd.read_excel(filePath_01,sheet_name = 'Zhengzhou2004').T
df6 = pd.read_excel(filePath_01,sheet_name = 'Zhengzhou2005').T
df7 = pd.read_excel(filePath_01,sheet_name = 'Zhengzhou2006').T
df8 = pd.read_excel(filePath_01,sheet_name = 'Zhengzhou2007').T
df9 = pd.read_excel(filePath_01,sheet_name = 'Zhengzhou2008').T
df10 = pd.read_excel(filePath_01,sheet_name = 'Zhengzhou2009').T
df11 = pd.read_excel(filePath_01,sheet_name = 'Zhengzhou2010').T
df12 = pd.read_excel(filePath_01,sheet_name = 'Zhengzhou2011').T
df13 = pd.read_excel(filePath_01,sheet_name = 'Zhengzhou2012').T
df14 = pd.read_excel(filePath_01,sheet_name = 'Zhengzhou2013').T
df15 = pd.read_excel(filePath_01,sheet_name = 'Zhengzhou2014').T
df16 = pd.read_excel(filePath_01,sheet_name = 'Zhengzhou2015').T


s1 = df1[1]
s2 = df2[1]
s3 = df3[1]
s4 = df4[1]
s5 = df5[1]
s6 = df6[1]
s7 = df7[1]
s8 = df8[1]
s9 = df9[1]
s10 = df10[1]
s11 = df11[1]
s12 = df12[1]
s13 = df13[1]
s14 = df14[1]
s15 = df15[1]
s16 = df16[1]

dq = pd.concat([s1,s2,s3,s4,s5,s6,s7,s8,s9,s10,s11,s12,s13,s14,s15,s16],axis = 1)
ds = dq.T
dm = ds.drop(columns=['Unnamed: 0'])
dm.reset_index(inplace=True,drop=True)
dm.rename(index ={0:2000,1:2001,2:2002,3:2003,4:2004,5:2005,6:2006,7:2007,8:2008,9:2009,10:2010,11:2011,12:2012,13:2013,14:2014,15:2015},inplace=True)

# %%
dm.plot(figsize = (10,12),subplots = True);
